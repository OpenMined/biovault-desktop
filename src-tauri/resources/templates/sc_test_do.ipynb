# %% [markdown]
# # Test: Data Owner (Client1) - SyftBox Mode
#
# Automated test notebook for the Data Owner workflow with SyftBox encryption.
# Run with: `jupyter execute sc_test_do.ipynb`

# %%
# # Run this cell to reinstall beaver + syftbox-sdk from local source (after code changes)
# import os
# biovault_root = os.path.normpath(os.path.join(os.environ.get('BIOVAULT_HOME', ''), '..', '..'))

# # Install syftbox-sdk first (beaver depends on it)
# syftbox_path = os.path.join(biovault_root, 'syftbox-sdk', 'python')
# if os.path.exists(syftbox_path):
#     !uv pip install -e {syftbox_path} -q
#     print(f'syftbox-sdk reinstalled from {syftbox_path}')

# # Install beaver
# beaver_path = os.path.join(biovault_root, 'biovault-beaver', 'python')
# if os.path.exists(beaver_path):
#     !uv pip install -e {beaver_path} -q
#     print(f'beaver reinstalled from {beaver_path}')

# print('\nRestart kernel to use new versions.')

# %%
import beaver

# %%
from beaver import Twin

# %%
beaver.show_debug()
# Out:
# ============================================================
# 🦫 BEAVER DEBUG INFO
# ============================================================
#
# 📦 Package Info:
#   Version: 0.1.24
#   Debug enabled: False
#   SyftBox available: True
#
# 🌍 Environment Variables:
#   SYFTBOX_EMAIL: client1@sandbox.local
#   SYFTBOX_DATA_DIR: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local
#   BEAVER_SESSION_ID: 3e273cdee725
#   BIOVAULT_HOME: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local
#   SYFTBOX_CONFIG_PATH: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/.syftbox/config.json
#   SYFTBOX_SERVER_URL: http://127.0.0.1:54334
#   VIRTUAL_ENV: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/3e273cdee725/.venv
#   PWD: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/3e273cdee725
#
# 📁 Working Directory:
#   /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/3e273cdee725
#
# 🐍 Python:
#   Version: 3.12.7 (main, Oct 16 2024, 07:12:08) [Clang 18.1.8 ]
#   Executable: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/3e273cdee725/.venv/bin/python3
#
# 📄 Session Config (session.json):
#   created_at: 2025-12-05T01:05:24.654732+00:00
#   jupyter_port: 55095
#   jupyter_url: http://localhost:55095/lab
#   name: test
#   owner: client1@sandbox.local
#   peer: client2@sandbox.local
#   session_id: 3e273cdee725
#
# ============================================================

# %%
bv = beaver.connect()
# Out:
# 🔄 Auto-load replies enabled for client1@sandbox.local (polling every 2.0s)

# %%
bv

# %%
requests = bv.session_requests()
requests
# Out:
# SessionRequests (1 pending):
#   [0] ⏳ bc2cf0ba... from client2@sandbox.local
#
# Use [index] or [session_id] to select, then .accept() to approve

# %%
peer = "client2@sandbox.local"

# %%
OWNER = "client1@sandbox.local"

# %%
session = requests[0].accept()
# Out:
# ✅ Session accepted: bc2cf0ba7524
#    Peer: client2@sandbox.local
#    Session folder: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/bc2cf0ba7524

# %%
session
# Out:
# 🟢 Session(
#     id='bc2cf0ba7524',
#     peer='client2@sandbox.local',
#     role='accepter',
#     status='active'
# )

# %%
# Create and publish Twin to session
numbers = Twin(
    private=1337,
    public=100,
    owner=OWNER,
    name="numbers",
)

# %%
# Publish to session (encrypted for peer only)
session.remote_vars["numbers"] = numbers
# Out:
# 🌍 Using PUBLIC data from Twin 'numbers...'
# 📢 Published Twin 'numbers' (public side available at: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/bc2cf0ba7524/data/a13a75d750e64c64a8bd7bfee95acbbf.beaver)

# %%
req = session.inbox()[0].load()
# Out:
# ✓ Loaded 'request_add_one_for_res' into globals

# %%
req
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⚡ Action: add_one_result
#    Request from: client2@sandbox.local
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Function: add_one
#
# ⚙️  Static Parameters:
#   • arg[0]: dict = {'_beaver_twin_ref': True, 'twin_id': '698f96a9...
#
# 💡 Next Steps:
#    .run_mock()   → Test on mock/public data (safe preview)
#    .run()        → Execute on real/private data
#    .run_both()   → Run on both mock & real for comparison
#    .reject(msg)  → Decline this request
#
# 🆔 IDs: comp=a8638cc80f0c... result=c283bfe9cc97...
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %%
res = request_add_one_for_res.run_both()
# Out:
# 🧪 Step 1/2: Testing on mock/public data...
# 🧪 Testing on mock/public data...
# 🔍 [post-execution] Figures to capture: 0
# 🔍 [post-execution] Already captured IDs: set()
# 🔒 Step 2/2: Executing on real/private data...
# ✓ Private result: int

# %%
res.approve()
# Out:
# ✅ Approving result for: add_one_result (twin_id=c283bfe9cc97..., comp_id=a8638cc80f0c..., result_id=c283bfe9cc97)
#    Sending to: client2@sandbox.local
# 🔒 Using PRIVATE data from Twin 'add_one_result...'
# ✓ Result sent to session folder: /Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/bc2cf0ba7524
# 💡 They can load it with: bv.inbox()['add_one_result'].load()
# PosixPath('/Users/madhavajay/dev/biovault-desktop/workspace3/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/bc2cf0ba7524/619c57d170b544e781db5a85be5d8961.beaver')

# %%
# Load single-cell data
data_dir = Path(DATA_ROOT + "single_cell/data")
private_path = data_dir / "sc_RNAseq_adata_downsampled_to5percent.private.h5ad"
mock_path = data_dir / "sc_RNAseq_adata_downsampled_to5percent.mock.h5ad"
sim_path = data_dir / "adata_simulated.h5ad"

# Create mock from simulated if needed
if not mock_path.exists() and sim_path.exists():
    print("[DO] Creating mock data from simulated...")
    adata_sim = sc.read(sim_path)
    adata_sim.obs.rename(columns={"pct_counts_in_top_50_genes": "pct_counts_mt"}, inplace=True)
    adata_sim.obs.rename(columns={"group": "cell_type"}, inplace=True)
    adata_sim.write_h5ad(mock_path)

adata_private = sc.read(private_path)
adata_mock = sc.read(mock_path)

print(f"[DO] Loaded private: {adata_private.n_obs} cells")
print(f"[DO] Loaded mock: {adata_mock.n_obs} cells")

assert adata_private.n_obs > 0, "Private data is empty"
assert adata_mock.n_obs > 0, "Mock data is empty"

# %%
beaver.sample_data.list_datasets()

# %%
# !uv pip install scanpy -q
# !uv pip install scikit-misc -q

# %%
beaver.sample_data.single_cell

# %%
# !uv pip install zstandard

# %%
patient_sc = beaver.sample_data.single_cell.twin()

# %%
patient_sc

# %%
# import sys
# from pathlib import Path

# # Configuration
# TIMEOUT = 120.0
# USER_EMAIL = "client1@sandbox.local"
# PEER_EMAIL = "client2@sandbox.local"
# DATA_DIR = Path.cwd()

# %%
# import scanpy as sc
# import anndata as ad
# from beaver import Twin
# from beaver.runtime import TrustedLoader
# import beaver

# # Connect with SyftBox backend
# bv = beaver.connect(
#     user=USER_EMAIL,
#     data_dir=DATA_DIR,
# )
# print(f"[DO] Connected as {bv.user}")
# print(f"[DO] SyftBox enabled: {bv.syftbox_enabled}")

# %%
import scanpy as sc
import anndata as ad
from beaver import Twin
from beaver.runtime import TrustedLoader
import beaver

# Connect with SyftBox backend

# %%
bv = beaver.connect()
print(f"[DO] Connected as {bv.user}")
print(f"[DO] SyftBox enabled: {bv.syftbox_enabled}")

# %%
# # Register AnnData serialization
# @TrustedLoader.register(ad.AnnData)
# def anndata_serialize_file(obj, path):
#     obj.write_h5ad(path)

# @TrustedLoader.register(ad.AnnData)
# def anndata_deserialize_file(path):
#     return ad.read_h5ad(path)

# print("[DO] Registered AnnData loader")

# %%
requests = bv.session_requests()
requests

# %%
# Wait for session request from DS
import time
TIMEOUT = 30
print("[DO] Waiting for session request from DS...")
session = None
deadline = time.monotonic() + TIMEOUT

while time.monotonic() < deadline:
    requests = bv.session_requests()
    if len(requests) > 0:
        # Accept the first request
        session = requests[0].accept()
        print(f"[DO] Accepted session from {requests[0].requester}")
        print(f"[DO] Session ID: {session.session_id}")
        break
    time.sleep(1.0)

assert session is not None, "Timeout waiting for session request"

# %%
# !pwd

# %%
DATA_ROOT = "/Users/madhavajay/dev/biovault-beaver/workspace1/notebooks/"

# %%
from pathlib import Path

# %%
beaver.show_debug()

# %%
USER_EMAIL = "client1@sandbox.local"

# %%
# Create and publish Twin to session
patient_sc = Twin(
    private=adata_private,
    public=adata_mock,
    owner=USER_EMAIL,
    name="patient_sc",
)

# Publish to session (encrypted for peer only)
session.remote_vars["patient_sc"] = patient_sc
print("[DO] Published patient_sc Twin to session")

# Track processed requests
processed_requests = set()

# %%
# Request 1: Violin plot
print("[DO] Waiting for request 1/4 (violin)...")
bv.wait_for_message(timeout=TIMEOUT, poll_interval=1.0)

# %%
# Find the first unprocessed computation request in inbox
inbox = bv.inbox()
request_envs = [e for e in inbox if e.name and e.name.startswith("request_") and e.name not in processed_requests]
assert len(request_envs) > 0, "No new request found in inbox"
request_env = request_envs[0]
print(f"[DO] Received: {request_env.name}")

# Load it - this injects the request into globals
request_env.load()
processed_requests.add(request_env.name)

# The loaded variable name is the envelope name
request_obj = globals()[request_env.name]
print(f"[DO] Running: {request_env.name}")

result = request_obj.run_both()
assert result is not None, "run_both() returned None"

result.approve()
print("[DO] ✓ Request 1 complete")

# %%
result.show_figures("both")

# %%
# Request 2: Embedding
print("[DO] Waiting for request 2/4 (embedding)...")
bv.wait_for_message(timeout=TIMEOUT, poll_interval=1.0)

inbox = bv.inbox()
request_envs = [e for e in inbox if e.name and e.name.startswith("request_") and e.name not in processed_requests]
assert len(request_envs) > 0, "No new request found in inbox"
request_env = request_envs[0]
print(f"[DO] Received: {request_env.name}")

request_env.load()
processed_requests.add(request_env.name)
request_obj = globals()[request_env.name]
print(f"[DO] Running: {request_env.name}")

result = request_obj.run_both()
assert result is not None, "run_both() returned None"

result.approve()
print("[DO] ✓ Request 2 complete")

# %%
# Inspect captured figures (mock/public and private)
result.show_figures('both')

# %%
# Request 3: PCA variance
print("[DO] Waiting for request 3/4 (pca)...")
bv.wait_for_message(timeout=TIMEOUT, poll_interval=1.0)

inbox = bv.inbox()
request_envs = [e for e in inbox if e.name and e.name.startswith("request_") and e.name not in processed_requests]
assert len(request_envs) > 0, "No new request found in inbox"
request_env = request_envs[0]
print(f"[DO] Received: {request_env.name}")

request_env.load()
processed_requests.add(request_env.name)
request_obj = globals()[request_env.name]
print(f"[DO] Running: {request_env.name}")

result = request_obj.run_both()
assert result is not None, "run_both() returned None"

result.approve()
print("[DO] ✓ Request 3 complete")

# %%
# Inspect captured figures (mock/public and private)
result.show_figures('both')

# %%
# Request 4: UMAP
print("[DO] Waiting for request 4/4 (umap)...")
bv.wait_for_message(timeout=TIMEOUT, poll_interval=1.0)

inbox = bv.inbox()
request_envs = [e for e in inbox if e.name and e.name.startswith("request_") and e.name not in processed_requests]
assert len(request_envs) > 0, "No new request found in inbox"
request_env = request_envs[0]
print(f"[DO] Received: {request_env.name}")

request_env.load()
processed_requests.add(request_env.name)
request_obj = globals()[request_env.name]
print(f"[DO] Running: {request_env.name}")

result = request_obj.run_both()
assert result is not None, "run_both() returned None"

result.approve()
print("[DO] ✓ Request 4 complete")

# %%
# Inspect captured figures (mock/public and private)
result.show_figures('both')

# %%
# Final assertions
print("\n" + "="*50)
print("[DO] TEST PASSED")
print("[DO] Successfully handled 4 computation requests")
print("="*50)
