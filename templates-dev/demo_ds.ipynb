# %% [markdown]
# # Test: Data Scientist (Client2) - SyftBox Mode
#
# Automated test notebook for the Data Scientist workflow with SyftBox encryption.
# Run with: `jupyter execute sc_test_ds.ipynb`

# %%
import beaver
bv = beaver.ctx()
session = bv.active_session()
bv.datasets
# Out:
# 🟢 Active session loaded: 794753c92ddd
#    Peer: client1@sandbox.local
# DatasetRegistry(owners=[client1@sandbox.local])

# %%
dataset = bv.datasets["client1@sandbox.local"]["test"]

# %%
dataset
# Out:
# Dataset(name=test, assets=[df])

# %%
dataset.df.load()
# Out:
# 🔒 Loading PRIVATE data for Twin 'df'
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⚠️  Code Execution Required
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📦 Loading: dataset_loader.csv
#    From: /Users/madhavajay/dev/biovaults/datasets/test_csv/real_data.csv
#
# 📋 Code to execute:
#
#     1 │ def load(path):
#     2 │     import pandas as pd
#     3 │     return pd.read_csv(path, sep=',')
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Execute this code? [y/N]:  y
#    ✓ Loading data...
#    ✓ Loaded: DataFrame
#      item  units  price
# 0   apple     10    1.5
# 1  banana      8    0.8
# 2  orange     12    1.2

# %%
# !uv pip install pandas
# Out:
# Audited 1 package in 4ms

# %%
dataset.df
# Out:
# Twin [DATASET ASSET] df
#   Owner: client1@sandbox.local
#   Asset: dataset_loader.csv
#   Type: unknown
#   Path: /Users/madhavajay/dev/biovault-desktop/workspace2/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/public/biovault/datasets/test/assets/mock_data.csv
#   Data: 🌍 Public (unloaded)
#   ID: 6229daeb...
#
# Deserializer: (runs automatically)
#    1 │ def load(path):
#    2 │     import pandas as pd
#    3 │     return pd.read_csv(path, sep=',')
#
# 💡 data = asset.load()  # returns the loaded object

# %%
dataset.df.load()
# Out:
# 🌍 Loading PUBLIC data for Twin 'df'
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⚠️  Code Execution Required
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📦 Loading: dataset_loader.csv
#    From: /Users/madhavajay/dev/biovault-desktop/workspace2/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/public/biovault/datasets/test/assets/mock_data.csv
#
# 📋 Code to execute:
#
#     1 │ def load(path):
#     2 │     import pandas as pd
#     3 │     return pd.read_csv(path, sep=',')
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Execute this code? [y/N]:  y
#    ✓ Loading data...
#    ✓ Loaded: DataFrame
#      item  units  price
# 0   apple     10    1.5
# 1  banana      8    0.8
# 2  orange     12    1.2

# %%
dataset.df.public
# Out:
#      item  units  price
# 0   apple      2   1.40
# 1  banana      3   0.75
# 2  orange      1   1.10

# %%
from typing import Any
import pandas as pd

@bv
def sum_price(df: pd.DataFrame) -> float:
    """
    Sum the values in the 'price' column of a DataFrame.
    Assumes 'price' is numeric or convertible to numeric.
    """
    return pd.to_numeric(df["price"], errors="coerce").sum()

# %%
result = sum_price(dataset.df)

# %%
result.public
# Out:
# np.float64(3.25)

# %%
result.private
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⚡ Action: sum_price_result
#    Request from: client1@sandbox.local
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Function: sum_price
#
# ⚠️  WARNING: Function accesses global state!
#    These variables are NOT passed as parameters:
#    • bv
#    • pd
#    💡 This may cause different results on remote execution!
#
# ⚙️  Static Parameters:
#   • arg[0]: dict = {'_beaver_twin_ref': True, 'twin_id': '6229daeb...
#
# 💡 Next Steps:
#    .run_mock()   → Test on mock/public data (safe preview)
#    .run()        → Execute on real/private data
#    .run_both()   → Run on both mock & real for comparison
#    .reject(msg)  → Decline this request
#
# 🆔 IDs: comp=ab4021868422... result=da216b3a567d...
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %%
result.request_private()
# Out:
# 📨 Sending computation request to client1@sandbox.local
#    Function: sum_price
#    Result: result
# ✓ Sent to /Users/madhavajay/dev/biovault-desktop/workspace2/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/794753c92ddd/7b438f04ea424b11827b4c49f66b7cb7.beaver
# 💡 Result will auto-update when client1@sandbox.local approves

# %%
session.inbox()[0].load()
# Out:
# ✓ Loaded 'request_sum_price_for_result' into globals
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⚡ Action: sum_price_result
#    Request from: client1@sandbox.local
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Function: sum_price
#
# ⚠️  WARNING: Function accesses global state!
#    These variables are NOT passed as parameters:
#    • bv
#    • pd
#    💡 This may cause different results on remote execution!
#
# ⚙️  Static Parameters:
#   • arg[0]: dict = {'_beaver_twin_ref': True, 'twin_id': '6229daeb...
#
# 💡 Next Steps:
#    .run_mock()   → Test on mock/public data (safe preview)
#    .run()        → Execute on real/private data
#    .run_both()   → Run on both mock & real for comparison
#    .reject(msg)  → Decline this request
#
# 🆔 IDs: comp=ab4021868422... result=da216b3a567d...
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %%
request_sum_price_for_result
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⚡ Action: sum_price_result
#    Request from: client1@sandbox.local
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Function: sum_price
#
# ⚠️  WARNING: Function accesses global state!
#    These variables are NOT passed as parameters:
#    • bv
#    • pd
#    💡 This may cause different results on remote execution!
#
# ⚙️  Static Parameters:
#   • arg[0]: dict = {'_beaver_twin_ref': True, 'twin_id': '6229daeb...
#
# 💡 Next Steps:
#    .run_mock()   → Test on mock/public data (safe preview)
#    .run()        → Execute on real/private data
#    .run_both()   → Run on both mock & real for comparison
#    .reject(msg)  → Decline this request
#
# 🆔 IDs: comp=ab4021868422... result=da216b3a567d...
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %%
request_sum_price_for_result.run_mock()
# Out:
# 🧪 Testing on mock/public data...
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ComputationResult: sum_price_result
#   Request from: client1@sandbox.local
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🌍 Twin: sum_price_result (MOCK DATA - SAFE)
#   🔒 Private    (not available) 💡 .request_private()
#   🌍 Public    np.float64(3.25)    ← .value uses this
#   Owner: client1@sandbox.local
#   Live: ⚫ Disabled
#   IDs: twin=da216b3a... private=97ad9302... public=6d22d67c...
#
#   💡 Actions:
#      .approve_mock()      - Send mock result back
#      .reject(message)     - Reject with explanation
#      .data                - Access Twin to inspect/modify

# %%
res = request_sum_price_for_result.run()
# Out:
# ⚙️  Executed: sum_price_result = sum_price(...)
#    From: client1@sandbox.local
#    Context: client1@sandbox.local
# ✓ Execution complete

# %%
res.approve()
# Out:
# ✅ Approving result for: sum_price_result (twin_id=da216b3a567d..., comp_id=ab4021868422..., result_id=da216b3a567d)
#    Sending to: client1@sandbox.local
# 🔒 Using PRIVATE data from Twin 'sum_price_result...'
# ✓ Result sent to session folder: /Users/madhavajay/dev/biovault-desktop/workspace2/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/794753c92ddd
# 💡 They can load it with: bv.inbox()['sum_price_result'].load()
# PosixPath('/Users/madhavajay/dev/biovault-desktop/workspace2/biovault/sandbox/client1@sandbox.local/datasites/client1@sandbox.local/shared/biovault/sessions/794753c92ddd/9b0d5a9e79c54f4ba1e30455df2b655a.beaver')

# %%
bv.inbox()[1].load()
# Out:
# 🔄 Twin merge skipped private (dst_id=da216b3a567d..., src_id=da216b3a567d..., dst_private=float64, src_private=float, placeholder=False, reason=dst_private_already_set)
# ✓ Loaded 'sum_price_result' into globals
# 🔒 Twin: sum_price_result (REAL DATA - SENSITIVE)
#   🔒 Private    3.5    ← .value uses this
#   🌍 Public    (not set)
#   Live: ⚫ Disabled
#   IDs: twin=da216b3a... private=f948ba94... public=b1c6472b...

# %%
result.private
# Out:
# np.float64(3.5)

# %%
import beaver
bv = beaver.ctx()
dataset = bv.datasets["kj@kj.dev"]["genotype"]
# Out:
# 🔄 Auto-load replies enabled for client1@sandbox.local (polling every 2.0s)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 3
#       1 import beaver
#       2 bv = beaver.ctx()
# ----> 3 dataset = bv.datasets["kj@kj.dev"]["genotype"]
#
# File ~/dev/biovault-desktop/workspace2/biovault/biovault-beaver/python/src/beaver/datasets.py:153, in _DatasetOwnerView.__getitem__(self, dataset_name)
#     151 resources = self._load_index()
#     152 if dataset_name not in resources:
# --> 153     raise KeyError(f"Dataset '{dataset_name}' not found for {self.owner}")
#     154 res = resources[dataset_name]
#     155 dataset_path = res.path
#
# KeyError: "Dataset 'genotype' not found for kj@kj.dev"

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/dev/biovaults/me@madhavajay.com/sessions/b918d4b7a60c/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~/dev/biovaults/me@madhavajay.com/sessions/b918d4b7a60c/.venv/lib/python3.12/site-packages/IPython/lib/pretty.py:412, in RepresentationPrinter.pretty(self, obj)
#     401                         return meth(obj, self, cycle)
#     402                 if (
#     403                     cls is not object
#     404                     # check if cls defines __repr__
#    (...)    410                     and callable(_safe_getattr(cls, "__repr__", None))
#     411                 ):
# --> 412                     return _repr_pprint(obj, self, cycle)
#     414     return _default_pprint(obj, self, cycle)
#     415 finally:
#
# File ~/dev/biovaults/me@madhavajay.com/sessions/b918d4b7a60c/.venv/lib/python3.12/site-packages/IPython/lib/pretty.py:787, in _repr_pprint(obj, p, cycle)
#     785 """A pprint that just redirects to the normal repr function."""
#     786 # Find newlines and replace them with p.break_()
# --> 787 output = repr(obj)
#     788 lines = output.splitlines()
#     789 with p.group():
#
# File ~/dev/biovaults/me@madhavajay.com/sessions/b918d4b7a60c/.venv/lib/python3.12/site-packages/beaver/datasets.py:509, in Dataset.__repr__(self)
#     508 def __repr__(self) -> str:
# --> 509     assets = ", ".join(self.assets())
#     510     return f"Dataset(name={self.name}, assets=[{assets}])"
#
# TypeError: sequence item 7: expected str instance, int found
#         <div style='font-family: monospace; border-left: 3px solid #FF9800; padding-left: 10px;'>
#             <b>Dataset:</b> genotype<br>
#             <div style='color: #666; margin-top:2px;'>net.biovault.datasets:1.0.0 • v1.0.0</div>
#             <div style='margin-top:6px;'>Dataset containing 9 files (Genotype)</div>
#             <div style='margin-top:6px; font-size: 12px; color: #777;'>
#                 public_url: <code>syft://kj@kj.dev/public/biovault/datasets/genotype/dataset.yaml</code>
#             </div>
#             <table style='margin-top:10px; border-collapse: collapse;'>
#                 <thead>
#                     <tr>
#                         <th style='padding:4px 8px; text-align:left;'>Asset</th>
#                         <th style='padding:4px 8px; text-align:left;'>Type</th>
#                         <th style='padding:4px 8px; text-align:left;'>Mock</th>
#                         <th style='padding:4px 8px; text-align:left;'>Mock Info</th>
#                         <th style='padding:4px 8px; text-align:left;'>Private</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr><td><b>000000_carika</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>103704_x_x_gsav3_dtc_grch38_07_01_2025</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>111442_x_x_gsav3_dtc_grch38_07_01_2025</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>117292_x_x_gsav3_dtc_grch38_07_01_2025</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>123364_x_x_gsav3_dtc_grch38_07_01_2025</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>256789_combined_genome</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>356789_eric_uhden_full_20110718111059</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>45678920120718021406</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>55678920170909061937</b></td><td>twin</td><td>✓</td><td>txt • 29.5MB</td><td>✓</td></tr>
#                 </tbody>
#             </table>
#         </div>

# %%
import beaver
beaver.dev() # install dev packages only in local dev mode
# beaver.show_debug()
# session.open() # open in finder
# Out:
# syftbox-sdk not found at /Users/madhavajay/dev/syftbox-sdk/python
# beaver not found at /Users/madhavajay/dev/biovault-beaver/python
#
# Restart kernel to use new versions.

# %%
# !uv pip install -U syftbox-sdk

# %%
import beaver
bv = beaver.ctx()
dataset = bv.datasets["kj@kj.dev"]["genotype"]
# Out:
# 🔄 Auto-load replies enabled for me@madhavajay.com (polling every 2.0s)

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/dev/biovaults/me@madhavajay.com/sessions/b918d4b7a60c/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~/dev/biovaults/me@madhavajay.com/sessions/b918d4b7a60c/.venv/lib/python3.12/site-packages/IPython/lib/pretty.py:412, in RepresentationPrinter.pretty(self, obj)
#     401                         return meth(obj, self, cycle)
#     402                 if (
#     403                     cls is not object
#     404                     # check if cls defines __repr__
#    (...)    410                     and callable(_safe_getattr(cls, "__repr__", None))
#     411                 ):
# --> 412                     return _repr_pprint(obj, self, cycle)
#     414     return _default_pprint(obj, self, cycle)
#     415 finally:
#
# File ~/dev/biovaults/me@madhavajay.com/sessions/b918d4b7a60c/.venv/lib/python3.12/site-packages/IPython/lib/pretty.py:787, in _repr_pprint(obj, p, cycle)
#     785 """A pprint that just redirects to the normal repr function."""
#     786 # Find newlines and replace them with p.break_()
# --> 787 output = repr(obj)
#     788 lines = output.splitlines()
#     789 with p.group():
#
# File ~/dev/biovaults/me@madhavajay.com/sessions/b918d4b7a60c/.venv/lib/python3.12/site-packages/beaver/datasets.py:509, in Dataset.__repr__(self)
#     508 def __repr__(self) -> str:
# --> 509     assets = ", ".join(self.assets())
#     510     return f"Dataset(name={self.name}, assets=[{assets}])"
#
# TypeError: sequence item 7: expected str instance, int found
#         <div style='font-family: monospace; border-left: 3px solid #FF9800; padding-left: 10px;'>
#             <b>Dataset:</b> genotype<br>
#             <div style='color: #666; margin-top:2px;'>net.biovault.datasets:1.0.0 • v1.0.0</div>
#             <div style='margin-top:6px;'>Dataset containing 9 files (Genotype)</div>
#             <div style='margin-top:6px; font-size: 12px; color: #777;'>
#                 public_url: <code>syft://kj@kj.dev/public/biovault/datasets/genotype/dataset.yaml</code>
#             </div>
#             <table style='margin-top:10px; border-collapse: collapse;'>
#                 <thead>
#                     <tr>
#                         <th style='padding:4px 8px; text-align:left;'>Asset</th>
#                         <th style='padding:4px 8px; text-align:left;'>Type</th>
#                         <th style='padding:4px 8px; text-align:left;'>Mock</th>
#                         <th style='padding:4px 8px; text-align:left;'>Mock Info</th>
#                         <th style='padding:4px 8px; text-align:left;'>Private</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr><td><b>000000_carika</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>103704_x_x_gsav3_dtc_grch38_07_01_2025</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>111442_x_x_gsav3_dtc_grch38_07_01_2025</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>117292_x_x_gsav3_dtc_grch38_07_01_2025</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>123364_x_x_gsav3_dtc_grch38_07_01_2025</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>256789_combined_genome</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>356789_eric_uhden_full_20110718111059</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>45678920120718021406</b></td><td>twin</td><td>✗</td><td>—</td><td>✓</td></tr><tr><td><b>55678920170909061937</b></td><td>twin</td><td>✓</td><td>txt • 29.5MB</td><td>✓</td></tr>
#                 </tbody>
#             </table>
#         </div>

# %%
# session

# %%
# !uv pip install scikit-misc scanpy -q
import beaver
import scanpy as sc # really slow first load

# %%
bv = beaver.ctx()
session = bv.active_session()
# Out:
# 🟢 Active session loaded: b918d4b7a60c
#    Peer: kj@kj.dev

# %%
session
# Out:
# 🟢 Session with kj@kj.dev
#    ID: b918d4b7a60c...
#    Role: owner
#    Status: active
#
# 📥 session.inbox():
#    InboxView(/Users/madhavajay/dev/biovaults/me@madhavajay.com/datasites/kj@kj.dev/shared/biovault/sessions/b918d4b7a60c): empty

# %%
session

# %%
session.wait_for_remote_var("number")

# %%
session.peer_remote_vars["number"].load()

# %%
number.private

# %%
number.public

# %%
@bv
def add_one(number):
    return number + 1

# %%
res = add_one(number)
res

# %%
res.public

# %%
res.request_private()

# %%
bv.wait_for_response(res)

# %%
res.private

# %%
# session.open()

# %%
assert False # some small bugs below on waiting on object timing

# %%
session.peer_remote_vars

# %%
data = session.wait_for_remote_var("patient_sc", auto_accept=False)

# %%
patient_sc = session.peer_remote_vars["patient_sc"].load(auto_accept=True)

# %%
patient_sc

# %% [markdown]
# ## Step 1: Violin Plot

# %%
patient_sc.public

# %%
# session.open() # open in finder

# %%
@bv
def make_violin(adata):
    print("n_cells:", adata.n_obs)
    sc.pl.violin(
        adata, ["n_genes_by_counts", "total_counts", "pct_counts_mt"],
        size=0,
        multi_panel=True
    )
    return plt.gcf()

violin_result = make_violin(patient_sc)

# %%
violin_result

# %%
# Display captured figures for mock run
violin_result.show_figures('public')

# %%
print("[DS] Requesting private execution...")
violin_result.request_private()

# %%
bv.wait_for_response(violin_result)

# %%
TIMEOUT = 60
print("[DS] Waiting for violin result...")
env, _ = bv.wait_for_message(timeout=TIMEOUT, poll_interval=1.0)
assert env is not None, "Timeout waiting for violin result"

assert violin_result.private is not None, "Private result not received"
print(f"[DS] ✓ Violin private result received")
if violin_result.private_stdout:
    print(f"[DS] Private stdout: {violin_result.private_stdout[:50]}...")

# %%
bv.inbox()[0].load()

# %%
violin_result.show_figures("both")

# %% [markdown]
# ## Step 2: Embedding Plot

# %%
print("[DS] Running embedding analysis...")

@bv
def show_embedding(adata):
    print("n_cells:", adata.n_obs)
    return sc.pl.embedding(
        adata,
        basis='X_umap',
        color=['pct_counts_mt', 'cell_type'],
        ncols=1, size=15,
        frameon=False,
        show=False
    )

embedding_result = show_embedding(patient_sc)

assert embedding_result is not None, "Embedding computation returned None"
print(f"[DS] Embedding public figures: {len(embedding_result.public_figures)}")

# %%
print("[DS] Requesting private execution...")
embedding_result.request_private()

print("[DS] Waiting for embedding result...")
env, _ = bv.wait_for_message(timeout=TIMEOUT, poll_interval=1.0)
assert env is not None, "Timeout waiting for embedding result"

print(f"[DS] ✓ Embedding private result received")

# %% [markdown]
# ## Step 3: PCA Variance

# %%
print("[DS] Running PCA variance analysis...")

@bv
def plot_pca_variance(adata):
    adata.layers['raw_counts'] = adata.X.copy()
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    sc.pp.highly_variable_genes(adata, flavor='seurat_v3', layer='raw_counts', n_top_genes=5000)
    sc.pp.pca(adata, use_highly_variable=True)
    with plt.rc_context({'figure.figsize': (4, 3)}):
        sc.pl.pca_variance_ratio(adata, n_pcs=50)

pca_result = plot_pca_variance(patient_sc)

assert pca_result is not None, "PCA computation returned None"
print(f"[DS] PCA public figures: {len(pca_result.public_figures)}")

# %%
print("[DS] Requesting private execution...")
pca_result.request_private()

print("[DS] Waiting for PCA result...")
env, _ = bv.wait_for_message(timeout=TIMEOUT, poll_interval=1.0)
assert env is not None, "Timeout waiting for PCA result"

print(f"[DS] ✓ PCA private result received")

# %% [markdown]
# ## Step 4: UMAP Embedding

# %%
print("[DS] Running UMAP embedding analysis...")

@bv
def umap_embedding(adata):
    sc.pp.neighbors(adata, n_pcs=50)
    sc.tl.umap(adata)
    return sc.pl.embedding(
        adata,
        basis='X_umap',
        color=['cell_type'],
        ncols=1, size=15,
        frameon=False,
        show=True
    )

umap_result = umap_embedding(patient_sc)

assert umap_result is not None, "UMAP computation returned None"
print(f"[DS] UMAP public figures: {len(umap_result.public_figures)}")

# %%
print("[DS] Requesting private execution...")
umap_result.request_private()

print("[DS] Waiting for UMAP result...")
env, _ = bv.wait_for_message(timeout=TIMEOUT, poll_interval=1.0)
assert env is not None, "Timeout waiting for UMAP result"

print(f"[DS] ✓ UMAP private result received")

# %%
# Final verification
print("\n" + "="*50)
print("[DS] TEST PASSED")
print("[DS] Successfully completed all 4 analysis steps:")
print("  1. Violin plot")
print("  2. Embedding plot")
print("  3. PCA variance")
print("  4. UMAP embedding")
print("="*50)

# Verify inbox has all results
inbox = bv.inbox()
print(f"\n[DS] Inbox contains {len(inbox)} messages")
assert len(inbox) >= 4, f"Expected at least 4 results in inbox, got {len(inbox)}"
